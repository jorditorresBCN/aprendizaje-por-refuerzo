# %%
import gym
env = gym.make('FrozenLake-v0', is_slippery=False)
env.env.P
# Out:
# {0: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 4, 0.0, False)],
#   2: [(1.0, 1, 0.0, False)],
#   3: [(1.0, 0, 0.0, False)]},
#  1: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 5, 0.0, True)],
#   2: [(1.0, 2, 0.0, False)],
#   3: [(1.0, 1, 0.0, False)]},
#  2: {0: [(1.0, 1, 0.0, False)],
#   1: [(1.0, 6, 0.0, False)],
#   2: [(1.0, 3, 0.0, False)],
#   3: [(1.0, 2, 0.0, False)]},
#  3: {0: [(1.0, 2, 0.0, False)],
#   1: [(1.0, 7, 0.0, True)],
#   2: [(1.0, 3, 0.0, False)],
#   3: [(1.0, 3, 0.0, False)]},
#  4: {0: [(1.0, 4, 0.0, False)],
#   1: [(1.0, 8, 0.0, False)],
#   2: [(1.0, 5, 0.0, True)],
#   3: [(1.0, 0, 0.0, False)]},
#  5: {0: [(1.0, 5, 0, True)],
#   1: [(1.0, 5, 0, True)],
#   2: [(1.0, 5, 0, True)],
#   3: [(1.0, 5, 0, True)]},
#  6: {0: [(1.0, 5, 0.0, True)],
#   1: [(1.0, 10, 0.0, False)],
#   2: [(1.0, 7, 0.0, True)],
#   3: [(1.0, 2, 0.0, False)]},
#  7: {0: [(1.0, 7, 0, True)],
#   1: [(1.0, 7, 0, True)],
#   2: [(1.0, 7, 0, True)],
#   3: [(1.0, 7, 0, True)]},
# ...

# %%
import gym
actions = {'Left': 0, 'Down': 1, 'Right': 2, 'Up': 3 }
good_plan = (2 * ['Down']) + (2 * ['Right']) + ['Down'] + ['Right']

env = gym.make('FrozenLake-v0', is_slippery=False)
env.reset()
env.render()
for action in good_plan:
    new_state, reward, done, info = env.step(actions[action])
    env.render()
    if done:
       break
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG

# %%
import gym
env = gym.make('FrozenLake-v0')

env.env.P
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, False)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   2: [(0.3333333333333333, 4, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)],
#   3: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, True)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False)],
#   2: [(0.3333333333333333, 5, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   3: [(0.3333333333333333, 2, 0.0, False),
# ...

# %%
env.reset()
env.render()
for action in good_plan:
    new_state, reward, done, info = env.step(actions[action])
    env.render()
    if done:
       break
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
